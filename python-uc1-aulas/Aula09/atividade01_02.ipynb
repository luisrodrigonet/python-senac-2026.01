# %%
import random
qt_elementos=random.randint(1,151)
numeros=[]
for i in range(qt_elementos):
    numeros.append(random.randint(1,999))
par=[]
impar=[]
for valor in numeros :
    if valor % 2 == 0:
        par.append(valor)
    else :
        impar.append(valor)
print(f"Numeros pares   :\n\t {par} \n")
print(f"Numeros impares :\n\t {impar} \n")
print(f"Qt Numeros pares     : {len(par):4} \n")
print(f"Qt Numeros impares   : {len(impar):4} \n")
# Out:
# Numeros pares   :
# 	 [414, 290, 554, 990, 18, 116, 306, 542, 228, 488, 816, 692, 910, 964, 254, 484, 134, 976, 370, 290, 152, 878, 204, 826, 980, 948, 98, 92, 770, 2, 416, 478, 204, 76, 76, 522, 320, 788, 116, 944, 248, 904, 372, 480, 430, 752, 124, 282, 274, 502, 934, 214, 642, 498, 762, 342, 878, 504, 730, 630, 98, 608, 234, 14, 636, 112, 368, 76, 814, 910, 798, 874, 114, 740, 416, 138]
#
# Numeros impares :
# 	 [211, 571, 747, 363, 285, 733, 57, 207, 611, 817, 783, 29, 743, 855, 305, 815, 107, 19, 313, 295, 517, 107, 951, 747, 151, 347, 819, 113, 953, 335, 201, 479, 605, 791, 237, 383, 231, 959, 401, 473, 251, 895, 331, 865, 867, 431, 939, 987, 749, 39, 495, 965, 437, 785, 163, 561]
#
# Qt Numeros pares     :   76
#
# Qt Numeros impares   :   56
