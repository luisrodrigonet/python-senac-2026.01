# %%
frutasT=("Limao", "Pera", "Maca", "Abacate")
#frutasT.append("Laranja")
frutasL=["Limao", "Pera", "Maca", "Abacate"]
frutasL.append("Laranja")
indice=0
for fruta in frutasL :
    print (f"{indice} - {fruta}")
    indice+=1
# Out:
# 0 - Limao
# 1 - Pera
# 2 - Maca
# 3 - Abacate
# 4 - Laranja

# %%
for indice in range(5) :
    print(f"Indice: {indice} - Posição : {indice+1} - {frutasL[indice]}" )
# Out:
# Indice: 0 - Posição : 1 - Limao
# Indice: 1 - Posição : 2 - Pera
# Indice: 2 - Posição : 3 - Maca
# Indice: 3 - Posição : 4 - Abacate
# Indice: 4 - Posição : 5 - Laranja

# %%
contador=0
while (contador <= 5) :
    print (f"O valor do contator é .:{contador}:.")
    contador+=1
print (f"Fim !!!!!")
# Out:
# O valor do contator é .:0:.
# O valor do contator é .:1:.
# O valor do contator é .:2:.
# O valor do contator é .:3:.
# O valor do contator é .:4:.
# O valor do contator é .:5:.
# Fim !!!!!

# %%
matriz=[
    [1,2,3],
    ["A","B","C"],
    [4,"D",5]
]

# %%
print(matriz)
# Out:
# [[1, 2, 3], ['A', 'B', 'C'], [4, 'D', 5]]

# %%
for linha in matriz:
    print ("[ ",end="")
    for elemento in linha :
        print (f"{elemento}, ",end="")
    print ("]",end="")
    print ()
print("Fim !")
# Out:
# [ 1, 2, 3, ]
# [ A, B, C, ]
# [ 4, D, 5, ]
# Fim !
